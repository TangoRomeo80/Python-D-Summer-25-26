# %%
# Simple distance calculation (Euclidian)
import numpy as np

penguin_a = np.array([40.0, 20.0])
penguin_b = np.array([45.0, 15.0])

distance = np.sqrt(np.sum((penguin_a - penguin_b) ** 2))
distance
# Out:
# np.float64(7.0710678118654755)
